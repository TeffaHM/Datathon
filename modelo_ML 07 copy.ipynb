# %% [markdown]
# ## Modelo 03 Forest Regression
#
# Como parte del bootcamp de Henry de Data Science se realiza un modelo para predecir el número de bicicletas.

# %% [markdown]
# ### Exploración de datos
#
# El objetivo de la primera parte del notebook es realizar una exploración de los datos del Dataset bike_train.xlsx

# %% [markdown]
# 1. Librerías a usarse:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import xgboost as xgb

# %% [markdown]
# 2. Importamos los archivos como dataframes

# %%
bike_train = pd.read_excel('bike_train.xlsx')
bike_test = pd.read_excel('bike_test.xlsx')
bike_train.head(5)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bike_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11999 entries, 0 to 11998
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     11999 non-null  int64
#  1   dteday      11999 non-null  datetime64[ns]
#  2   season      11999 non-null  int64
#  3   yr          11999 non-null  int64
#  4   mnth        11999 non-null  int64
#  5   hr          11999 non-null  int64
#  6   holiday     11999 non-null  int64
#  7   weekday     11999 non-null  int64
#  8   workingday  11999 non-null  int64
#  9   weathersit  11999 non-null  int64
#  10  temp        11999 non-null  float64
#  11  atemp       11999 non-null  float64
#  12  hum         11999 non-null  float64
#  13  windspeed   11999 non-null  float64
#  14  casual      11999 non-null  int64
#  15  registered  11999 non-null  int64
#  16  cnt         11999 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 1.6 MB

# %% [markdown]
# 3. Eliminamos las columnas que no servirían como input. Instant es un anterior index y dteday no lo vamos a requerir ya que no lo estamos trabajando como serie de tiempo

# %%
drop_columns = ['instant','dteday', 'casual', 'registered', 'windspeed', 'mnth']
train = bike_train.drop(drop_columns, axis =1)
test = bike_test.drop(['instant','dteday', 'windspeed', 'mnth'], axis =1)
train.head()
# Out:
#    season  yr  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1   0   0        0        6           0           1  0.24  0.2879
# 1       1   0   1        0        6           0           1  0.22  0.2727
# 2       1   0   2        0        6           0           1  0.22  0.2727
# 3       1   0   3        0        6           0           1  0.24  0.2879
# 4       1   0   4        0        6           0           1  0.24  0.2879
#
#     hum  cnt
# 0  0.81   16
# 1  0.80   40
# 2  0.80   32
# 3  0.75   13
# 4  0.75    1

# %%
y = train['cnt']
X = train.drop(['cnt'], axis=1)

# %%
def rmsle(y_true, y_pred, convertExp=True):
    # 지수변환
    if convertExp:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
        
    # 로그변환 후 결측값을 0으로 변환
    log_true = np.nan_to_num(np.log(y_true+1))
    log_pred = np.nan_to_num(np.log(y_pred+1))
    
    # RMSLE 계산
    output = np.sqrt(np.mean((log_true - log_pred)**2))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

rmsle_scorer = metrics.make_scorer(rmsle, greater_is_better=False)

# %%
from sklearn.ensemble import RandomForestRegressor

randomforest_model = RandomForestRegressor()
# 그리드서치 객체 생성
rf_params = {'random_state':[42], 'n_estimators':[100, 120, 140]}
gridsearch_random_forest_model = GridSearchCV(estimator=randomforest_model,
                                              param_grid=rf_params, n_jobs=-1,
                                              scoring=rmsle_scorer, cv=5)

log_y = np.log(y)
gridsearch_random_forest_model.fit(X, log_y)
print('최적 하이퍼파라미터 :', gridsearch_random_forest_model.best_estimator_)
# Out:
# c:\Users\Jhoel\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan]
#   warnings.warn(
# 최적 하이퍼파라미터 : RandomForestRegressor(random_state=42)

# %%
preds = gridsearch_random_forest_model.best_estimator_.predict(X)
error = rmsle(log_y, preds)
error

# %%
preds
# Out:
# array([3.01158927, 3.4158761 , 2.69060268, ..., 4.80749789, 4.44689203,
#        3.91614748])

# %%
randomforest_preds = gridsearch_random_forest_model.best_estimator_.predict(test)

# %%
randomforest_preds_cnt= np.exp(randomforest_preds)

# %%
randomforest_preds_cnt
# Out:
# array([10.17384314,  8.98847062, 18.12132399, ..., 95.59461313,
#        97.52944862, 43.33338701])

# %%
randomforest_preds_cnt = pd.DataFrame(randomforest_preds_cnt, columns = ['pred'])
randomforest_preds_cnt = np.round(randomforest_preds_cnt,2)
randomforest_preds_cnt.to_csv('TeffaHM_v15_randomforest_GridSearch_sin_viento_sin_mes.csv', header=True, index=False)

# %%
print(error)
# Out:
# None

# %% [markdown]
# 3.1 Evaluamos las correlaciones lineales, nos quedamos con las variables con las que tiene mayor correlación y las que tienen correlación entre ellas

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.20, random_state=0)

# %% [markdown]
# 5. Seleccionamos la variables de entrada y las variables de salida

# %%
model = XGBRegressor(gpu_id=0)

# %% [markdown]
# 7.1 Hyperparameter tunning

# %%
from sklearn.model_selection import GridSearchCV
xgb = XGBRegressor(gpu_id = 0)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=0, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
predicciones= xgb.predict(X_validation)

# %%
predicciones
# Out:
# array([135.24422  ,  32.989067 ,   2.7947333, ..., 351.0246   ,
#        175.6465   ,  27.288723 ], dtype=float32)

# %%
pred_xgb_v5 = xgb.predict(test)
pred_xgb_v5 = pd.DataFrame(pred_xgb_v5, columns = ['pred'])
pred_xgb_v5 = np.round(pred_xgb_v5,2)
pred_xgb_v5.to_csv('TeffaHM_v14_xgb_day.csv', header=True, index=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_validation,predicciones, squared = False)
# Out:
# 34.159297718989066

# %%
tuned_parameters = {
    'max_depth' : [3,4,5,6],
    'min_child_weight' : [1,2,3,4,5,6],
    'learning_rate' : [0.01,0.05,0.1,0.2, 0.3],
}

# %%
clf = GridSearchCV(xgb, param_grid=tuned_parameters, scoring = 'neg_root_mean_squared_error', cv=5, verbose = 2)

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=4; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=3; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=3; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=3; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=3; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=4; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=4; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=4; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, min_child_weight=6; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=1; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=2; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=4; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=4; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=1; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=2; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=3; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=4; total time=   0.1s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=1; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=2; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=3; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=3; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=3; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=3; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=3; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=4; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=5; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=3, min_child_weight=6; total time=   0.0s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.1, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.2, max_depth=5, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.2, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=3, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=4, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=1; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=2; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=3; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=4; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=5; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=5, min_child_weight=6; total time=   0.1s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=1; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=2; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=3; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=4; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=5; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=6; total time=   0.2s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=6; total time=   0.3s
# [CV] END .learning_rate=0.3, max_depth=6, min_child_weight=6; total time=   0.2s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     callbacks=None, colsample_bylevel=1,
#                                     colsample_bynode=1, colsample_bytree=1,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=0, gpu_id=0, grow_policy='depthwise',
#                                     importance_type=None,
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_bin=256,
#                                     max_cat_...p=0,
#                                     max_depth=6, max_leaves=0,
#                                     min_child_weight=1, missing=nan,
#                                     monotone_constraints='()', n_estimators=100,
#                                     n_jobs=0, num_parallel_tree=1,
#                                     predictor='auto', random_state=0,
#                                     reg_alpha=0, reg_lambda=1, ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_child_weight': [1, 2, 3, 4, 5, 6]},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
predicciones_2 = clf.predict(X_validation)
predicciones_2
# Out:
# array([172.51233 ,  45.763134,   9.892303, ..., 331.39844 , 144.10652 ,
#         56.15449 ], dtype=float32)

# %%
print(clf.best_score_)
# Out:
# -35.06993906336568

# %%
mean_squared_error(y_validation,predicciones_2, squared = False)
# Out:
# 34.33967599388628

# %%
pred_xgb_v5 = clf.predict(test)
pred_xgb_v5 = pd.DataFrame(pred_xgb_v5, columns = ['pred'])
pred_xgb_v5 = np.round(pred_xgb_v5,2)
pred_xgb_v5.to_csv('TeffaHM_v13_xgb_GridSearch_day.csv', header=True, index=False)

# %% [markdown]
# 8. Entrenamos el modelo

# %% [markdown]
# Random Forest Regression
